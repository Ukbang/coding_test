# %% [markdown]
# ![웹 캡처_1-11-2022_124548_cdn.discordapp.com.jpeg](data:image/jpeg;base64,...)

# %%
x = int(input())
y = input().split()

if x != len(y):
    print('Error')
elif x == len(y):
    for i in range(len(y)):
        if int(y[i]) == i:
            print(i)
            break
        elif i == len(y)-1:
            print(-1)
            break
# Out:
# 7
# -15 -4 2 8 9 13 15
# 2
