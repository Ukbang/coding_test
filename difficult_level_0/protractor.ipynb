# %% [markdown]
# ![image.png](attachment:image.png)

# %%
angle = 80

# %%
def solution(angle):
    if angle < 90:
        return 1
    elif angle == 90:
        return 2 
    elif angle < 180:
        return 3 
    else:
        return 4

# %%
solution(angle)
# Out:
# 1
