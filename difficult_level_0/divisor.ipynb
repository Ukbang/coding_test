# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(my_string):
    return eval(my_string)

# 내장함수 eval은 문자열 수식을 처리해준다
# a = "2 + 5 + 12 + 22" == eval(a) -> 41
# x = 10 a = "x * 10 + 5" == eval(a) -> 105
