# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [293, 1000, 395, 678, 94]
delete_list = [94, 777, 104, 1000, 1, 12]

# %%
def solution(arr, delete_list):
    for i in range(len(delete_list)):
        try:
            del arr[arr.index(delete_list[i])]
        except:
            pass
    return arr
