# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 0
control = "wsdawsdassw"

# %%
def solution(n, control):
    control_dict = {'w':'+1', 's':'-1', 'a':'-10', 'd':'+10'}
    return n+eval(''.join([control_dict[s] for s in control]))
