# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myString = "axbxcxdx"

# %%
myString = "dxccxbbbxaaaa"

# %%
# 정답
def solution(myString):
    myString = sorted(myString.split('x'))
    return myString if '' not in myString else [i for i in myString if i != '']

# %%
# 틀림
def solution(myString):
    myString = sorted(myString.split('x'))
    if '' in myString: 
        myString.remove('')
        return myString
    else:
        return myString

# %%
solution(myString)
# Out:
# ['a', 'b', 'c', 'd']
