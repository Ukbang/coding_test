# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = "dfjardstddetckdaccccdegk"
code = 4

# %%
def solution(cipher, code):
    return ''.join([cipher[j] for j in [(code*i)-1 for i in range(1, (len(cipher)//code)+1)]])

# %%
solution(a, code)
# Out:
# 'attack'
