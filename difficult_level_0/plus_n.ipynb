# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numbers = [34, 5, 71, 29, 100, 34]
n = 123

# %%
def solution(numbers, n):
    result = 0
    for i in numbers:
        result += i
        if result > n:
            return result
