# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 29423568910029463929

# %%
def solution(order):
    order = str(order)
    for i in range(10):
        if i % 3 == 0 and i != 0:
            pass
        else:
            order = order.replace(str(i), '')
    return len(order)

# %%
solution(a)
# Out:
# 9
