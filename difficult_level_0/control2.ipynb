# %% [markdown]
# ![image.png](attachment:image.png)

# %%
log = [0, 1, 0, 10, 0, 1, 0, 10, 0, -1, -2, -1]

# %%
def solution(log):
    wasd_dict = {1:'w', -1:'s', 10:'d', -10:'a'}
    return ''.join([wasd_dict[log[i]-log[i-1]] for i in range(1, len(log))])
