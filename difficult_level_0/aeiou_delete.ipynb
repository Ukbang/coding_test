# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(my_string):
    _dict = {'a':'', 'e':'','i':'','o':'','u':''}
    for d in _dict:
        my_string = my_string.replace(d, _dict[d])
    return my_string
