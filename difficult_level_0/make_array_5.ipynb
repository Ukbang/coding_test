# %% [markdown]
# ![image.png](attachment:image.png)

# %%
intStrs = ["0123456789","9876543210","9999999999999"]
k = 50000
s = 5
l = 5

# %%
def solution(intStrs, k, s, l):
    return [int(i[s:s+l]) for i in intStrs if i[s:s+l] > str(k)]
