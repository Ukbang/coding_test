# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_string = "ihrhbakrfpndopljhygc"
m = 4
c = 2

# %%
def solution(my_string, m, c):
    return ''.join([my_string[i:m+i][c-1] for i in range(0, len(my_string), m)])

# %%
solution(my_string, m, c)
# Out:
# 'happy'
