# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 1234

# %%
def solution(n):
    n = str(n)
    length = len(n)
    return sum([int(n[i]) for i in range(length)])

# %%
solution(a)
# Out:
# 10
