# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
spell = ['p', 'o', 's']
dic = ["sod", "eocd", "qixm", "adio", "soo"]
spell2 = ["z", "d", "x"]
dic2 = ["def", "dww", "dzx", "loveaw"]

# %%
def solution(spell, dic):
    for _dic in dic:
        count = 0
        for i in range(len(spell)):
            if spell[i] in _dic:
                count += 1
            if count == len(spell):
                return 1
    return 2
