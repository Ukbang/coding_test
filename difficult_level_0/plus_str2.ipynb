# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_strings = ["progressive", "hamburger", "hammer", "ahocorasick"]
parts = [[0, 4], [1, 2], [3, 5], [7, 7]]

# %%
def solution(my_strings, parts):
    return ''.join([s[parts[i][0]:parts[i][1]+1] for i,s in enumerate(my_strings)])
