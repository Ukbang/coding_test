# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sides = [199, 72, 222]

# %%
def solution(sides):
    return 1 if sides.pop(sides.index(max(sides))) < sum(sides) else 2

# %%
solution(sides)
# Out:
# 2
