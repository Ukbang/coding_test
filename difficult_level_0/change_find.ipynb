# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myString = 'ABBAA'
pat = 'AABB'

# %%
def solution(myString, pat):
    myString = ''.join([i.replace('A','B') if i=='A' else i.replace('B','A') for i in myString])
    return 1 if pat in myString else 0

# %%
solution(myString, pat)
# Out:
# 1
