# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myString = "abcdevwxyz"

# %%
apb_list = ["a", "b", "c", "d", "e", "f", "g", "h"]

# %%
def solution(myString):
    apb_list = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k"]
    return ''.join([i if i not in apb_list else 'l' for i in myString])
