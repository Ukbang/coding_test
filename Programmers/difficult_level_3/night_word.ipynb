# %% [markdown]
# ![image.png](attachment:image.png)

# %%
works = [4,3,3]
n = 4

# %%
def solution(works, n):
    if sum(works) <= n:
        return 0
    else:
        night = list(map(lambda x:x**2), works)
