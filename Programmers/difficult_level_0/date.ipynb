# %% [markdown]
# ![image.png](attachment:image.png)

# %%
date1 = [2021,12,28]
date2 = [2021,12,29]

# %%
def solution(date1, date2):
    return int(int(''.join(list(map(lambda x:str(x) , date1)))) < int(''.join(list(map(lambda x:str(x) , date2)))))

# %%
solution(date1, date2)
# Out:
# 1
