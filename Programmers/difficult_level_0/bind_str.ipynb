# %% [markdown]
# ![image.png](attachment:image.png)

# %%
strArr = ["a","bc","d","efg","hi"]

# %%
def solution(strArr):
    result = [0]*30
    for i in strArr: 
        result[len(i)-1] += 1
    return max(result)

# %%
solution(strArr)
# Out:
# 2
