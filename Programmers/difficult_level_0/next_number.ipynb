# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(common):
    if (common[1] - common[0]) == (common[2] - common[1]):
        dis = common[1] - common[0]
        result = common[-1] + dis
    else:
        dis = common[1] // common[0]
        result = common[-1] * dis

    return result
