# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_string = "bananas"
is_suffix = "nas"

# %%
def solution(my_string, is_suffix):
    if is_suffix in my_string and len(my_string) >= len(is_suffix):
        return 1 if my_string[-len(is_suffix):]==is_suffix else 0
    else:
        return 1 if my_string==is_suffix else 0
