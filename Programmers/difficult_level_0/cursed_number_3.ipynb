# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 30

# %%
def solution(n):
    num = 0
    for i in range(1, n+1):
        num += 1
        while num%3==0 or str(3) in str(num):
            num += 1
            
    return num

# %%
solution(n)
# Out:
# 59
