# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(my_str, n):
    cut = 0
    result = []
    while len(my_str) > cut:
        result.append(my_str[cut:cut+n])
        cut += n

    return result

# %%
solution(a, 6)
# Out:
# ['abc1Ad', 'dfggg4', '556b']
