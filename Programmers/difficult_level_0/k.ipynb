# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = 3
j = 30
k = 3

# %%
numlist = str(list(range(i,j+1)))

# %%
def solution(i,j,k):
    return str(list(range(i, j+1))).count(str(k))

# %%
solution(i,j,k)
# Out:
# 4
