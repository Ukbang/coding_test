# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_list = [3, 4, 5, 2, 5, 4, 6, 7, 3, 7, 2, 2, 1]

# %%
def solution(num_list):
    result = 1
    for i in num_list:
        if len(num_list) <= 10:
            result *= i
        else:
            return sum(num_list)
    return result
