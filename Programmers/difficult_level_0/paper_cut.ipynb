# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(m, n):
    m_cut = m - 1
    n_cut = (n - 1) * m

    return m_cut + n_cut
