# %% [markdown]
# ![image.png](attachment:image.png)

# %%
strlist = ['Hello', 'What', 'your', 'name?']

# %%
def solution(strlist):
    return [len(s) for s in strlist]

# %%
solution(strlist)
# Out:
# [5, 4, 4, 5]
