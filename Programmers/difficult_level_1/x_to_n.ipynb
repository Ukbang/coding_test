# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(x, n):
    if x==0:
        return [x]*n
    elif x < 0:
        return [j for j in range(x,x*n-1,x)]
    else:   
        return [i for i in range(x,x*n+1,x)]
