# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price = 3
money = 20
count = 4

# %%
def solution(price, money, count):
    result = sum([price*i for i in range(1, count+1)])
    return 0 if money >= result else abs(money-result)

# %%
solution(price, money, count)
# Out:
# 10
