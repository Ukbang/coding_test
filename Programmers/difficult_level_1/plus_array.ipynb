# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr1 = [[1,2],[2,3]]
arr2 = [[3,4],[5,6]]

# %%
def solution(arr1, arr2):
    return [[arr1[idx][idx2] + arr2[idx][idx2] for idx2 in range(len(arr1[idx]))] for idx in range(len(arr1))]

# %%
solution(arr1, arr2)
# Out:
# [[4, 6], [7, 9]]
