# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(ingredient):
    hamburger = ""
    result = 0
    for num in ingredient:
        hamburger += f"{num}"
        if len(hamburger) >= 4:
            if hamburger[-4:] == "1231":
                hamburger = hamburger[:-4]
                result += 1

    return result
